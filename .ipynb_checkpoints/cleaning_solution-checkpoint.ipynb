# %% [markdown]
# # Cleaning Quiz: Udacity's Course Catalog
# It's your turn! Udacity's [course catalog page](https://www.udacity.com/courses/all) has changed since the last video was filmed. One notable change is the introduction of  _schools_.
#
# In this activity, you're going to perform similar actions with BeautifulSoup to extract the following information from each course listing on the page:
# 1. The course name - e.g. "Data Analyst"
# 2. The school the course belongs to - e.g. "School of Data Science"

# %% [markdown]
# ### Step 1: Get text from Udacity's course catalog web page
# You can use the `requests` library to do this.
#
# Outputting all the javascript, CSS, and text may overload the space available to load this notebook, so we omit a print statement here.

# %%
# import statements
import requests
from bs4 import BeautifulSoup

# %%
# fetch web page
r = requests.get("https://www.udacity.com/courses/all")

# %% [markdown]
# ### Step 2: Use BeautifulSoup to remove HTML tags
# Use `"lxml"` rather than `"html5lib"`.
#
# Again, outputting all the results may overload the space available to load this notebook, so we omit a print statement here.

# %%
soup = BeautifulSoup(r.text, "lxml")

# %% [markdown]
# ### Step 3: Find all course summaries
# Use the BeautifulSoup's `find_all` method to select based on tag type and class name. Just ike in the video, you can right click on the item, and click "Inspect" to view its html on a web page.

# %%
# Find all course summaries
summaries = soup.find_all("li", {"class":"catalog-cards__list__item"})
print('Number of Courses:', len(summaries))
# Out:
# Number of Courses: 1

# %% [markdown]
# ### Step 4: Inspect the first summary to find selectors for the course name and school
# Tip: `.prettify()` is a super helpful method BeautifulSoup provides to output html in a nicely indented form! Make sure to use `print()` to ensure whitespace is displayed properly.

# %%
# print the first summary in summaries
print(summaries[0].prettify())
# Out:
# <ul class="catalog-cards__list">
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Data Engineer" class="card__top" href="/course/data-engineer-nanodegree--nd027">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Data Science
#       </h3>
#       <h2 class="card__title__nd-name">
#        Data Engineer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Data Modeling, Data Pipelines, Data Lakes, Spark, Airflow
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Insight
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd027-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd027-expandable-content">
#     <div class="details__layout">
#      <p>
#       Data Engineering is the foundation for the new world of Big Data. Enroll now to build production-ready data infrastructure, an essential skill for advancing your data career.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Data Engineer." class="button btn button--primary" href="/course/data-engineer-nanodegree--nd027" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <a aria-label="Data Analyst" class="card__top" href="/course/data-analyst-nanodegree--nd002">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <h3 class="card__title__school greyed">
#        School of Data Science
#       </h3>
#       <h2 class="card__title__nd-name">
#        Data Analyst
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Data Wrangling, Matplotlib, Bootstrapping, Pandas &amp; NumPy, Statistics
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Kaggle
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd002-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd002-expandable-content">
#     <div class="details__layout">
#      <p>
#       Use Python, SQL, and statistics to uncover insights, communicate critical findings, and create data-driven solutions.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Data Analyst." class="button btn button--primary" href="/course/data-analyst-nanodegree--nd002" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <a aria-label="Introduction to Programming" class="card__top" href="/course/intro-to-programming-nanodegree--nd000">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <h3 class="card__title__school greyed">
#        School of Programming &amp; Development
#       </h3>
#       <h2 class="card__title__nd-name">
#        Introduction to Programming
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Introduction to Programming, HTML, CSS, Python
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd000-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd000-expandable-content">
#     <div class="details__layout">
#      <p>
#       Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Introduction to Programming." class="button btn button--primary" href="/course/intro-to-programming-nanodegree--nd000" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <a aria-label="Deep Learning" class="card__top" href="/course/deep-learning-nanodegree--nd101">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <h3 class="card__title__school greyed">
#        School of Artificial Intelligence
#       </h3>
#       <h2 class="card__title__nd-name">
#        Deep Learning
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Deep Learning, Neural Networks, Jupyter Notebooks, CNNs, GANs
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         AWS, Facebook Artificial Intelligence
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd101-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd101-expandable-content">
#     <div class="details__layout">
#      <p>
#       Deep learning is driving advances in artificial intelligence that are changing our world. Enroll now to build and apply your own deep neural networks to produce amazing solutions to important challenges.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Deep Learning." class="button btn button--primary" href="/course/deep-learning-nanodegree--nd101" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Full Stack Web Developer" class="card__top" href="/course/full-stack-web-developer-nanodegree--nd0044">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Programming &amp; Development
#       </h3>
#       <h2 class="card__title__nd-name">
#        Full Stack Web Developer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Python, JavaScript, PostgreSQL, Flask, Docker, Kubernetes
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd0044-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd0044-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn to design and develop powerful modern web applications that form the foundation for the apps, websites, and systems that people and businesses use every day.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Full Stack Web Developer." class="button btn button--primary" href="/course/full-stack-web-developer-nanodegree--nd0044" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="UX Designer" class="card__top" href="/course/ux-designer-nanodegree--nd578">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Business
#       </h3>
#       <h2 class="card__title__nd-name">
#        UX Designer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         User Research, User Experience, Prototyping, Interactive Design, User Interface Design, Usability Testing
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd578-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd578-expandable-content">
#     <div class="details__layout">
#      <p>
#       Design impactful user experiences for products in todayâs digital world.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about UX Designer." class="button btn button--primary" href="/course/ux-designer-nanodegree--nd578" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Data Scientist" class="card__top" href="/course/data-scientist-nanodegree--nd025">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Data Science
#       </h3>
#       <h2 class="card__title__nd-name">
#        Data Scientist
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Machine Learning, Deep Learning, Software Engineering
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Bertelsmann, Figure Eight, IBM Watson, Insight, Kaggle, Starbucks
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd025-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="advanced level" data-level="advanced">
#       </div>
#       <small aria-hidden="true">
#        advanced
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd025-expandable-content">
#     <div class="details__layout">
#      <p>
#       Build effective machine learning models, run data pipelines, build recommendation systems, and deploy solutions to the cloud with industry-aligned projects.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Data Scientist." class="button btn button--primary" href="/course/data-scientist-nanodegree--nd025" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Business Analytics" class="card__top" href="/course/business-analytics-nanodegree--nd098">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Business
#       </h3>
#       <h2 class="card__title__nd-name">
#        Business Analytics
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Excel &amp; Spreadsheets, SQL, Data Visualization, Data Dashboards
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Tableau, Mode
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd098-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd098-expandable-content">
#     <div class="details__layout">
#      <p>
#       Gain foundational data skills applicable to any industry. Collect and analyze data, model business scenarios, and communicate your findings with SQL, Excel, and Tableau.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Business Analytics." class="button btn button--primary" href="/course/business-analytics-nanodegree--nd098" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Self Driving Car Engineer" class="card__top" href="/course/self-driving-car-engineer-nanodegree--nd013">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Autonomous Systems
#       </h3>
#       <h2 class="card__title__nd-name">
#        Self Driving Car Engineer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Computer Vision, Deep Learning, Sensor Fusion, Localization, Self-Driving Cars
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Mercedes-Benz, Nvidia, Uber ATG, DiDi, McLaren
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd013-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="advanced level" data-level="advanced">
#       </div>
#       <small aria-hidden="true">
#        advanced
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd013-expandable-content">
#     <div class="details__layout">
#      <p>
#       Self-driving cars are set to revolutionize the way we live. This is transformational technology, on the cutting-edge of robotics, machine learning, software engineering, and mechanical engineering. In this program, youâll learn the skills and techniques used by self-driving car teams at the most advanced technology companies in the world.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Self Driving Car Engineer." class="button btn button--primary" href="/course/self-driving-car-engineer-nanodegree--nd013" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Programming for Data Science with Python" class="card__top" href="/course/programming-for-data-science-nanodegree--nd104">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Data Science
#       </h3>
#       <h2 class="card__title__nd-name">
#        Programming for Data Science with Python
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Python, Numpy &amp; Pandas, SQL, Git &amp; GitHub
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Mode
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd104-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd104-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn the fundamental programming tools for data professionals: Python, SQL, the Terminal and Git.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Programming for Data Science with Python." class="button btn button--primary" href="/course/programming-for-data-science-nanodegree--nd104" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <a aria-label="Machine Learning Engineer" class="card__top" href="/course/machine-learning-engineer-nanodegree--nd009t">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <h3 class="card__title__school greyed">
#        School of Artificial Intelligence
#       </h3>
#       <h2 class="card__title__nd-name">
#        Machine Learning Engineer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Machine Learning, Supervised Learning, Unsupervised Learning, Deep Learning
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Kaggle, AWS
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd009t-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd009t-expandable-content">
#     <div class="details__layout">
#      <p>
#       Become a machine learning engineer and apply predictive models to massive data sets in fields like education, finance, healthcare or robotics.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Machine Learning Engineer." class="button btn button--primary" href="/course/machine-learning-engineer-nanodegree--nd009t" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="C++" class="card__top" href="/course/c-plus-plus-nanodegree--nd213">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Autonomous Systems
#       </h3>
#       <h2 class="card__title__nd-name">
#        C++
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Data Structures &amp; Algorithms, Memory Management, Concurrency, Object Oriented Programming, C++
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd213-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd213-expandable-content">
#     <div class="details__layout">
#      <p>
#       Get hands-on experience by building five real-world projects.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about C++." class="button btn button--primary" href="/course/c-plus-plus-nanodegree--nd213" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <a aria-label="Digital Marketing" class="card__top" href="/course/digital-marketing-nanodegree--nd018">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <h3 class="card__title__school greyed">
#        School of Business
#       </h3>
#       <h2 class="card__title__nd-name">
#        Digital Marketing
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Digital Marketing, Social Media Marketing, Facebook Marketing, Search Engine Optimization, Search Engine Marketing, Display Ads, Search Ads
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Google, Hootsuite, HubSpot, MailChimp, Moz, Facebook
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd018-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd018-expandable-content">
#     <div class="details__layout">
#      <p>
#       Gain real-world experience running live campaigns as you learn from top experts in the field. Launch your career with a 360-degree understanding of digital marketing.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Digital Marketing." class="button btn button--primary" href="/course/digital-marketing-nanodegree--nd018" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="SQL" class="card__top" href="/course/learn-sql--nd072">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Data Science
#       </h3>
#       <h2 class="card__title__nd-name">
#        SQL
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         SQL, PostgreSQL, JOINs, Subqueries, Window Functions, Partitions, Data Cleaning, DDL, DML, Relational and Non-Relational Databases
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd072-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd072-expandable-content">
#     <div class="details__layout">
#      <p>
#       Master SQL, the core language for Big Data analysis, and enable insight-driven decision-making and strategy for your business.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about SQL." class="button btn button--primary" href="/course/learn-sql--nd072" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="AI Programming with Python" class="card__top" href="/course/ai-programming-python-nanodegree--nd089">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Artificial Intelligence
#       </h3>
#       <h2 class="card__title__nd-name">
#        AI Programming with Python
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Python, NumPy, Pandas, Matplotlib, PyTorch
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd089-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd089-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn Python, NumPy, Pandas, Matplotlib, PyTorch, Calculus, and Linear Algebraâthe foundations for building your own neural network.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about AI Programming with Python." class="button btn button--primary" href="/course/ai-programming-python-nanodegree--nd089" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Front End Web Developer" class="card__top" href="/course/front-end-web-developer-nanodegree--nd0011">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Programming &amp; Development
#       </h3>
#       <h2 class="card__title__nd-name">
#        Front End Web Developer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         JavaScript, HTML, CSS, Webpack, Flexbox, Node, Object-Oriented Programming
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd0011-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd0011-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn how to build high quality websites and dynamic applications to create stunning user experiences for the web.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Front End Web Developer." class="button btn button--primary" href="/course/front-end-web-developer-nanodegree--nd0011" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="AI Product Manager" class="card__top" href="/course/ai-product-manager-nanodegree--nd088">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Artificial Intelligence
#       </h3>
#       <h2 class="card__title__nd-name">
#        AI Product Manager
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         AI Products, Training ML Models, Annotating Datasets, Prototyping a Product
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Appen
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd088-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd088-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn to develop AI products that deliver business value. Build skills that help you compete in the new AI-powered world.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about AI Product Manager." class="button btn button--primary" href="/course/ai-product-manager-nanodegree--nd088" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Cloud DevOps Engineer" class="card__top" href="/course/cloud-dev-ops-nanodegree--nd9991">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Cloud Computing
#       </h3>
#       <h2 class="card__title__nd-name">
#        Cloud DevOps Engineer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         AWS, Configuration Management with Ansible, Continuous Integration / Continuous Deployment, Microservices with Kubernetes, CloudFormation
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd9991-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd9991-expandable-content">
#     <div class="details__layout">
#      <p>
#       Companies are looking for talented DevOps engineers to remain competitive in this agile world. Enroll now to operationalize infrastructure at scale and deliver applications and services at high velocity, an essential skill for advancing your career.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Cloud DevOps Engineer." class="button btn button--primary" href="/course/cloud-dev-ops-nanodegree--nd9991" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Artificial Intelligence for Trading" class="card__top" href="/course/ai-for-trading--nd880">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Artificial Intelligence
#       </h3>
#       <h2 class="card__title__nd-name">
#        Artificial Intelligence for Trading
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Momentum Trading Strategy, Smart Beta, Alpha Factors, Natural Language Processing, Deep Learning, Neural Networks
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         WorldQuant
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd880-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd880-expandable-content">
#     <div class="details__layout">
#      <p>
#       Complete real-world projects designed by industry experts, covering topics from asset management to trading signal generation. Master AI algorithms for trading, and build your career-ready portfolio.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Artificial Intelligence for Trading." class="button btn button--primary" href="/course/ai-for-trading--nd880" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="DevOps Engineer for Microsoft Azure" class="card__top" href="/course/devops-engineer-for-microsoft-azure-nanodegree--nd082">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Cloud Computing
#       </h3>
#       <h2 class="card__title__nd-name">
#        DevOps Engineer for Microsoft Azure
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Infrastructure as Code,  Configuration Management,  Agile Planning,  Continuous Integration,  Continuous Delivery,  Test Automation,  Monitoring
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Microsoft
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd082-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd082-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn how to deploy, test, and monitor cloud applications on Azure, one of the most popular cloud services platforms used by businesses across the globe.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about DevOps Engineer for Microsoft Azure." class="button btn button--primary" href="/course/devops-engineer-for-microsoft-azure-nanodegree--nd082" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Cloud Developer" class="card__top" href="/course/cloud-developer-nanodegree--nd9990">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="nanodegree">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Cloud Computing
#       </h3>
#       <h2 class="card__title__nd-name">
#        Cloud Developer
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         AWS, Microservices, Serverless Architecture, Kubernetes
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="nd9990-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="nd9990-expandable-content">
#     <div class="details__layout">
#      <p>
#       Cloud development is the foundation for the new world of software development. Enroll now to build and deploy production-ready full stack apps at scale on AWS, an essential skill for advancing your web development career.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
# ...
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop free">
#        Free
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Programming &amp; Development
#       </h3>
#       <h2 class="card__title__nd-name">
#        Intro to Psychology
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Pyschology, Research Methods, Biology
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         San Jose State University
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ps001-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ps001-expandable-content">
#     <div class="details__layout">
#      <p>
#       Go on a journey through psychological concepts and principles to enable you to gain a more in-depth understanding of human thought and behavior.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Intro to Psychology." class="button btn button--primary" href="/course/intro-to-psychology--ps001" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile free">
#      Free Program!
#     </span>
#     <a aria-label="Engagement &amp; Monetization | Mobile Games" class="card__top" href="/course/engagement-monetization-mobile-games--ud407">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="course">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop free">
#        Free
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Programming &amp; Development
#       </h3>
#       <h2 class="card__title__nd-name">
#        Engagement &amp; Monetization | Mobile Games
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Game Development, Monetization, Engagement
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Amazon Appstore for Android
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ud407-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ud407-expandable-content">
#     <div class="details__layout">
#      <p>
#       You will learn the most effective monetization strategies for your game, how to  keep your players interested and engaged, so that your game stands out in the app store.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Engagement &amp; Monetization | Mobile Games." class="button btn button--primary" href="/course/engagement-monetization-mobile-games--ud407" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile free">
#      Free Program!
#     </span>
#     <a aria-label="Get Your Startup Started" class="card__top" href="/course/get-your-startup-started--ud806">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="course">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop free">
#        Free
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Business
#       </h3>
#       <h2 class="card__title__nd-name">
#        Get Your Startup Started
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Entrepreneurship, Bootstrapping
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Google
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ud806-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ud806-expandable-content">
#     <div class="details__layout">
#      <p>
#       Acquire the know-how necessary to see your business grow towards its next milestone.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Get Your Startup Started." class="button btn button--primary" href="/course/get-your-startup-started--ud806" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile free">
#      Free Program!
#     </span>
#     <a aria-label="Introduction to Machine Learning Course" class="card__top" href="/course/intro-to-machine-learning--ud120">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="course">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop free">
#        Free
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Artificial Intelligence
#       </h3>
#       <h2 class="card__title__nd-name">
#        Introduction to Machine Learning Course
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Machine Learning, Supervised Learning, Unsupervised Learning, Evaluation Metrics, Data Manipulation
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ud120-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ud120-expandable-content">
#     <div class="details__layout">
#      <p>
#       This class will teach you the end-to-end process of investigating data through a machine learning lens. Learn online, with Udacity.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Introduction to Machine Learning Course." class="button btn button--primary" href="/course/intro-to-machine-learning--ud120" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile free">
#      Free Program!
#     </span>
#     <a aria-label="Material Design for Android Developers" class="card__top" href="/course/material-design-for-android-developers--ud862">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="course">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop free">
#        Free
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Programming &amp; Development
#       </h3>
#       <h2 class="card__title__nd-name">
#        Material Design for Android Developers
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Android Development, Material Design, Surfaces, Graphic Design
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Google
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ud862-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="intermediate level" data-level="intermediate">
#       </div>
#       <small aria-hidden="true">
#        intermediate
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ud862-expandable-content">
#     <div class="details__layout">
#      <p>
#       Learn and apply the material design principles that define Android's visual language to your apps.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Material Design for Android Developers." class="button btn button--primary" href="/course/material-design-for-android-developers--ud862" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Managing Remote Teams with Upwork" class="card__top" href="/course/managing-remote-teams-with-upwork--ud942">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="course">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        School of Business
#       </h3>
#       <h2 class="card__title__nd-name">
#        Managing Remote Teams with Upwork
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Team Management, Workforce Training, Business Strategy, Agile Management, Remote Work
#        </p>
#       </section>
#       <section>
#        <h4 class="text-content__text greyed">
#         In Collaboration With
#        </h4>
#        <p class="text-content__text">
#         Upwork
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ud942-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ud942-expandable-content">
#     <div class="details__layout">
#      <p>
#       Bring your remote-teams to the next level with hands-on skills to manage your remote workforce effectively.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Managing Remote Teams with Upwork." class="button btn button--primary" href="/course/managing-remote-teams-with-upwork--ud942" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="catalog-cards__list__item">
#   <article class="catalog-component">
#    <div class="catalog-component__card">
#     <span class="catalog-card-tag--mobile">
#      New Program!
#     </span>
#     <a aria-label="Product Manager Interview Preparation" class="card__top" href="/course/product-manager-interview-preparation--ud034">
#      <div class="card__image-container">
#       <div class="card__image-wrapper">
#        <div class="card__image-overlay" data-catalogtype="course">
#        </div>
#        <div class="card__image" style="background-image:url(...)">
#        </div>
#       </div>
#      </div>
#      <div class="card__title-container">
#       <span class="catalog-card-tag--desktop">
#        New
#       </span>
#       <h3 class="card__title__school greyed">
#        Career Advancement
#       </h3>
#       <h2 class="card__title__nd-name">
#        Product Manager Interview Preparation
#       </h2>
#      </div>
#      <div class="card__text-content">
#       <section>
#        <h4 class="text-content__text greyed">
#         Skills Covered
#        </h4>
#        <p class="text-content__text">
#         Product Management, Interview Preparation, Career Advancement, Product Strategy, Technical Interview
#        </p>
#       </section>
#      </div>
#     </a>
#     <div class="card__bottom">
#      <button aria-controls="ud034-expandable-content" aria-expanded="false" class="card__bottom__button">
#       Program Details
#      </button>
#      <div class="difficulty">
#       <div aria-label="beginner level" data-level="beginner">
#       </div>
#       <small aria-hidden="true">
#        beginner
#       </small>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="catalog-component__details" id="ud034-expandable-content">
#     <div class="details__layout">
#      <p>
#       Ace your product management interview by understanding how to answer key strategic, technical, and practical product questions.
#      </p>
#      <div class="layout__button-container">
#       <div class="reviews">
#       </div>
#       <a aria-label="Learn more about Product Manager Interview Preparation." class="button btn button--primary" href="/course/product-manager-interview-preparation--ud034" tabindex="-1">
#        Learn More
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </li>
# </ul>

# %% [markdown]
# Look for selectors contain the the courses title and school name text you want to extract. Then, use the `select_one` method on the summary object to pull out the html with those selectors. Afterwards, don't forget to do some extra cleaning to isolate the names (get rid of unnecessary html), as you saw in the last video.

# %%
# Extract course title
summaries[0].select_one("h2").get_text().strip()
# Out:
# 'Data Engineer'

# %%
# Extract school
summaries[0].select_one("h3").get_text().strip()
# Out:
# 'School of Data Science'

# %% [markdown]
# ### Step 5: Collect names and schools of ALL course listings
# Reuse your code from the previous step, but now in a loop to extract the name and school from every course summary in `summaries`!

# %%
courses = []
for summary in summaries:
    # append name and school of each summary to courses list
    title = summary.select_one("h2").get_text().strip()
    school = summary.select_one("h3").get_text().strip()
    courses.append((title, school))

# %%
# display results
print(len(courses), "course summaries found. Sample:")
courses[:20]
# Out:
# 1 course summaries found. Sample:
# [('Data Engineer', 'School of Data Science')]
